# %%
import pandas as pd

# %%
df1 = pd.read_excel('D:\python学习\pandas_test\挑战杯项目\城镇消费分类-2003-2018\城镇消费分类-2003-2018.xlsx',header=[0])

# %%
df1
# Out:
#            地区    年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003       5064.34       2238.91        558.07        487.37
# 1         北京市  2003      11123.84       3522.69        906.21        955.77
# 2         福建省  2003       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003       5298.91       1908.10        645.19        505.60
# 4         广东省  2003       9636.27       3583.72        559.90       1196.40
# ..        ...   ...           ...           ...           ...           ...
# 491       陕西省  2018      21966.40       5928.70       1728.20       4300.90
# 492       甘肃省  2018      22606.00       6491.30       1906.30       5060.80
# 493       青海省  2018      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018      24191.40       6899.70       2233.10       4287.20
#
# ...

# %%
bixu = (df1['城镇人均食品消费支出/元']+df1['城镇人均衣着消费支出/元']+df1['城镇人均交通和通信消费支出/元'])/df1['城镇人均现金消费支出/元']

# %%
df1['城市必须消费占比（人均消费支出）'] = bixu

# %%
df1.dtypes
# Out:
# 地区                    object
# 年份                     int64
# 城镇人均现金消费支出/元         float64
# 城镇人均食品消费支出/元         float64
# 城镇人均衣着消费支出/元         float64
# 城镇人均居住消费支出/元         float64
# 城镇人均家庭设备及用品消费支出/元    float64
# 城镇人均医疗保健消费支出/元       float64
# 城镇人均交通和通信消费支出/元      float64
# 城镇人均文教娱乐服务消费支出/元     float64
# 城镇人均其它消费支出/元         float64
# 城市必须消费占比（人均消费支出）     float64
# dtype: object

# %%
naiyong_city =(df1['城镇人均家庭设备及用品消费支出/元']+df1['城镇人均医疗保健消费支出/元']+df1['城镇人均文教娱乐服务消费支出/元']+df1['城镇人均其它消费支出/元'])/df1['城镇人均现金消费支出/元']

# %%
df1['城镇耐用品占比'] = naiyong_city

# %%
df1
# Out:
#            地区    年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003       5064.34       2238.91        558.07        487.37
# 1         北京市  2003      11123.84       3522.69        906.21        955.77
# 2         福建省  2003       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003       5298.91       1908.10        645.19        505.60
# 4         广东省  2003       9636.27       3583.72        559.90       1196.40
# ..        ...   ...           ...           ...           ...           ...
# 491       陕西省  2018      21966.40       5928.70       1728.20       4300.90
# 492       甘肃省  2018      22606.00       6491.30       1906.30       5060.80
# 493       青海省  2018      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018      24191.40       6899.70       2233.10       4287.20
#
# ...

# %%
df_ub = pd.read_excel('D:\python学习\pandas_test\挑战杯项目\农村消费分类-2003-2018\农村消费分类-2003-2018.xlsx',header=[0])

# %%
df_ub
# Out:
#          地区    年份  农村交通和通讯消费支出（元）  农村其他商品及服务消费支出（元）  农村医疗保健消费支出（元）  \
# 0       上海市  2003          587.02             86.55         332.77
# 1       云南省  2003           59.54             23.82          79.93
# 2    内蒙古自治区  2003          192.00             32.46         124.42
# 3       北京市  2003          393.35             82.22         356.31
# 4       吉林省  2003          173.82             37.98         153.75
# ..      ...   ...             ...               ...            ...
# 491     辽宁省  2018         1820.13            246.52        1529.09
# 492     重庆市  2018         1502.54            184.69        1075.11
# 493     陕西省  2018         1222.52            185.31        1241.78
# 494     青海省  2018         1765.20            250.82        1332.28
# 495    黑龙江省  2018         1632.54            231.56        1916.23
#
#      农村家庭设备及服务消费支出（元）  农村居住消费支出（元）  农村文教、娱乐用品及服务消费支出（元）  农村衣着消费支出（元）  \
# 0              296.51      1436.72               675.56       250.30
# ...

# %%
bixu_ub = (df_ub['农村食品消费支出（元）']+df_ub['农村衣着消费支出（元）']+df_ub['农村交通和通讯消费支出（元）'])/df_ub['农村居民现金消费支出']

# %%
df_ub['农村必须消费占比（消费性支出）'] = bixu_ub

# %%
naiyong_ub = (df_ub['农村医疗保健消费支出（元）']+df_ub['农村其他商品及服务消费支出（元）']+df_ub['农村家庭设备及服务消费支出（元）']+df_ub['农村文教、娱乐用品及服务消费支出（元）'])/df_ub['农村居民现金消费支出']

# %%
df_ub['农村耐用消费占比（消费性支出）'] = naiyong_ub

# %%
df_ub
# Out:
#          地区    年份  农村交通和通讯消费支出（元）  农村其他商品及服务消费支出（元）  农村医疗保健消费支出（元）  \
# 0       上海市  2003          587.02             86.55         332.77
# 1       云南省  2003           59.54             23.82          79.93
# 2    内蒙古自治区  2003          192.00             32.46         124.42
# 3       北京市  2003          393.35             82.22         356.31
# 4       吉林省  2003          173.82             37.98         153.75
# ..      ...   ...             ...               ...            ...
# 491     辽宁省  2018         1820.13            246.52        1529.09
# 492     重庆市  2018         1502.54            184.69        1075.11
# 493     陕西省  2018         1222.52            185.31        1241.78
# 494     青海省  2018         1765.20            250.82        1332.28
# 495    黑龙江省  2018         1632.54            231.56        1916.23
#
#      农村家庭设备及服务消费支出（元）  农村居住消费支出（元）  农村文教、娱乐用品及服务消费支出（元）  农村衣着消费支出（元）  \
# 0              296.51      1436.72               675.56       250.30
# ...

# %%
total = pd.merge(df1,df_ub,on=['地区','年份'])

# %%
total
# Out:
#            地区    年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003       5064.34       2238.91        558.07        487.37
# 1         北京市  2003      11123.84       3522.69        906.21        955.77
# 2         福建省  2003       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003       5298.91       1908.10        645.19        505.60
# 4         广东省  2003       9636.27       3583.72        559.90       1196.40
# ..        ...   ...           ...           ...           ...           ...
# 491       陕西省  2018      21966.40       5928.70       1728.20       4300.90
# 492       甘肃省  2018      22606.00       6491.30       1906.30       5060.80
# 493       青海省  2018      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018      24191.40       6899.70       2233.10       4287.20
#
# ...

# %%
df_custom_level = pd.read_excel('D:\python学习\pandas_test\挑战杯项目\消费水平-2003-2017\消费水平2003-2017.xlsx', header=[0])  #消费水平

# %%
total = pd.merge(total,df_custom_level,on=['地区','年份'],how='outer')

# %%
total
# Out:
#            地区    年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003       5064.34       2238.91        558.07        487.37
# 1         北京市  2003      11123.84       3522.69        906.21        955.77
# 2         福建省  2003       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003       5298.91       1908.10        645.19        505.60
# 4         广东省  2003       9636.27       3583.72        559.90       1196.40
# ..        ...   ...           ...           ...           ...           ...
# 491       陕西省  2018      21966.40       5928.70       1728.20       4300.90
# 492       甘肃省  2018      22606.00       6491.30       1906.30       5060.80
# 493       青海省  2018      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018      24191.40       6899.70       2233.10       4287.20
#
# ...

# %%
df_fin_index = pd.read_excel('D:\python学习\pandas_test\挑战杯项目\数字金融\数字金融指数.xlsx',header=[0])

# %%
df_fin_index
# Out:
#        年份        地区      数字金融指数    数字金融覆盖广度    数字金融使用深度    数字金融使用水平
# 0    2011       北京市   79.410000   97.530000   72.230000   32.590000
# 1    2011       天津市   60.580000   69.370000   53.330000   44.720000
# 2    2011       河北省   32.420000   18.460000   44.190000   57.150000
# 3    2011       山西省   33.410000   28.940000   21.610000   69.570000
# 4    2011    内蒙古自治区   28.890000   24.650000   30.270000   40.350000
# ..    ...       ...         ...         ...         ...         ...
# 243  2018       陕西省  295.947508  281.051868  277.148824  379.310946
# 244  2018       甘肃省  266.822973  261.289635  227.515067  356.538974
# 245  2018       青海省  263.123857  251.689489  235.312855  351.433032
# 246  2018   宁夏回族自治区  272.923427  274.251710  225.274783  355.139285
# 247  2018  新疆维吾尔自治区  271.839711  267.351171  232.936910  357.369973
#
# [248 rows x 6 columns]

# %%
total = pd.merge(total,df_fin_index,on=['年份','地区'],how='outer')

# %%
total
# Out:
#            地区    年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003       5064.34       2238.91        558.07        487.37
# 1         北京市  2003      11123.84       3522.69        906.21        955.77
# 2         福建省  2003       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003       5298.91       1908.10        645.19        505.60
# 4         广东省  2003       9636.27       3583.72        559.90       1196.40
# ..        ...   ...           ...           ...           ...           ...
# 491       陕西省  2018      21966.40       5928.70       1728.20       4300.90
# 492       甘肃省  2018      22606.00       6491.30       1906.30       5060.80
# 493       青海省  2018      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018      24191.40       6899.70       2233.10       4287.20
#
# ...

# %%
df_income_city = pd.read_excel('D:\python学习\pandas_test\挑战杯项目\可支配收入\城镇收入-2003-2018.xlsx',header=[0])
total = pd.merge(total,df_income_city,on=['地区','年份'],how='outer')

# %%
total
# Out:
#            地区    年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003       5064.34       2238.91        558.07        487.37
# 1         北京市  2003      11123.84       3522.69        906.21        955.77
# 2         福建省  2003       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003       5298.91       1908.10        645.19        505.60
# 4         广东省  2003       9636.27       3583.72        559.90       1196.40
# ..        ...   ...           ...           ...           ...           ...
# 491       陕西省  2018      21966.40       5928.70       1728.20       4300.90
# 492       甘肃省  2018      22606.00       6491.30       1906.30       5060.80
# 493       青海省  2018      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018      24191.40       6899.70       2233.10       4287.20
#
# ...

# %%
total.to_excel('D:\python学习\pandas_test\挑战杯项目\总表\测试.xlsx')

# %%
df_save = pd.read_excel('D:\python学习\pandas_test\挑战杯项目\城乡储蓄\城乡人均储蓄.xlsx',header=[0])

# %%
total = pd.merge(total, df_save, how='outer',on=['年份','地区'])

# %%
total
# Out:
#            地区    年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003       5064.34       2238.91        558.07        487.37
# 1         北京市  2003      11123.84       3522.69        906.21        955.77
# 2         福建省  2003       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003       5298.91       1908.10        645.19        505.60
# 4         广东省  2003       9636.27       3583.72        559.90       1196.40
# ..        ...   ...           ...           ...           ...           ...
# 491       陕西省  2018      21966.40       5928.70       1728.20       4300.90
# 492       甘肃省  2018      22606.00       6491.30       1906.30       5060.80
# 493       青海省  2018      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018      24191.40       6899.70       2233.10       4287.20
#
# ...

# %%
df_income_ub = pd.read_excel('D:\python学习\pandas_test\挑战杯项目\可支配收入\农村收入-2003-2018.xlsx',header=[0])

# %%
total = pd.merge(total,df_income_ub,on=['年份','地区'],how='outer')

# %%
total
# Out:
#            地区    年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003       5064.34       2238.91        558.07        487.37
# 1         北京市  2003      11123.84       3522.69        906.21        955.77
# 2         福建省  2003       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003       5298.91       1908.10        645.19        505.60
# 4         广东省  2003       9636.27       3583.72        559.90       1196.40
# ..        ...   ...           ...           ...           ...           ...
# 491       陕西省  2018      21966.40       5928.70       1728.20       4300.90
# 492       甘肃省  2018      22606.00       6491.30       1906.30       5060.80
# 493       青海省  2018      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018      24191.40       6899.70       2233.10       4287.20
#
# ...

# %%
df_thire_c = pd.read_excel('D:\python学习\pandas_test\挑战杯项目\第三产业.xlsx',header=[0])

# %%
total = pd.merge(total,df_thire_c,how='outer',on=['年份'])

# %%
total
# Out:
#            地区      年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003.0       5064.34       2238.91        558.07        487.37
# 1         北京市  2003.0      11123.84       3522.69        906.21        955.77
# 2         福建省  2003.0       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003.0       5298.91       1908.10        645.19        505.60
# 4         广东省  2003.0       9636.27       3583.72        559.90       1196.40
# ..        ...     ...           ...           ...           ...           ...
# 493       青海省  2018.0      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018.0      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018.0      24191.40       6899.70       2233.10       4287.20
# 496       NaN     NaN           NaN           NaN           NaN           NaN
# 497       NaN     NaN           NaN           NaN           NaN           NaN
#
# ...

# %%
total.to_excel('D:\python学习\pandas_test\挑战杯项目\总表\总表.xlsx')

# %%
total['城乡之间消费差'] = total['城镇人均现金消费支出/元']-total['农村居民现金消费支出']

# %%
total
# Out:
#            地区      年份  城镇人均现金消费支出/元  城镇人均食品消费支出/元  城镇人均衣着消费支出/元  城镇人均居住消费支出/元  \
# 0         安徽省  2003.0       5064.34       2238.91        558.07        487.37
# 1         北京市  2003.0      11123.84       3522.69        906.21        955.77
# 2         福建省  2003.0       7356.26       3104.80        576.18        878.94
# 3         甘肃省  2003.0       5298.91       1908.10        645.19        505.60
# 4         广东省  2003.0       9636.27       3583.72        559.90       1196.40
# ..        ...     ...           ...           ...           ...           ...
# 493       青海省  2018.0      22997.50       6351.20       2004.00       4235.40
# 494   宁夏回族自治区  2018.0      21976.70       5374.40       1952.90       4032.20
# 495  新疆维吾尔自治区  2018.0      24191.40       6899.70       2233.10       4287.20
# 496       NaN     NaN           NaN           NaN           NaN           NaN
# 497       NaN     NaN           NaN           NaN           NaN           NaN
#
# ...

# %%
total.to_excel('D:\python学习\pandas_test\挑战杯项目\总表\总表.xlsx')
